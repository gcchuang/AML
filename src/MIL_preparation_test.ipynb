# %%
import pandas as pd
import numpy as np
import os
import torch
from sklearn.model_selection import train_test_split
import utility_functions as uf

# %%
patches_size = 256
target_gene = "DNMT3A"
grid = []
output_path ="/home/weber50432/AML_image_processing/lib/"
slide_path = "/home/exon_storage1/aml_slide/"
grid_val = []
slide_list = uf.get_slides_list_number(f"{slide_path}otsu_1.0/")
# print(uf.make_paths_list("{}renameByUPN/".format(slide_path),slide_list))
target = uf.get_targets_list(target_gene,slide_list,"/home/weber50432/AML_image_processing/code_use_csv/changeSlideName.csv")

# %%
X = np.array(slide_list)
y = np.array(target)
# 將數據集按比例 6:2:2 分為訓練集、驗證集和測試集
# 找到標籤為1的樣本索引
positive_indices = np.where(y == 1)[0]

# 使用 train_test_split 函数分割樣本
# 首先將標籤為1的樣本分成訓練集、驗證集和測試集
train_pos, val_pos_test = train_test_split(positive_indices, test_size=0.4)
val_pos, test_pos = train_test_split(val_pos_test, test_size=0.5)

# 接下來將標籤為0的樣本分成訓練集、驗證集和測試集
train_neg, val_neg_test, y_train, y_val_test = train_test_split(np.where(y == 0)[0], y[np.where(y == 0)[0]], test_size=0.4)
val_neg, test_neg, y_val, y_test = train_test_split(val_neg_test, y_val_test, test_size=0.5)

# 將訓練集、驗證集和測試集的索引合併起來
train_indices = sorted(np.concatenate((train_pos, train_neg)))
val_indices = sorted(np.concatenate((val_pos, val_neg)))
test_indices = sorted(np.concatenate((test_pos, test_neg)))

# 根據索引提取對應的數據和標籤
X_train = X[train_indices].tolist()
X_val = X[val_indices].tolist()
X_test = X[test_indices].tolist()
y_train = y[train_indices].tolist()
y_val = y[val_indices].tolist()
y_test = y[test_indices].tolist()

# 計算各個集合的樣本數量
print(f"訓練集樣本數量：{len(X_train)}")
print(y_train.count(1))
# print(X_train[:20])
# print(y_train[:20])
print(f"驗證集樣本數量：{len(X_val)}")
print(y_val.count(1))
print(f"測試集樣本樣量：{len(X_test)}")
print(y_test.count(1))
# Out:
# 訓練集樣本數量：344
# 59
# 驗證集樣本數量：115
# 20
# 測試集樣本樣量：115
# 20

# %%
train_output = {
      "slides": uf.make_paths_list("{}renameByUPN/".format(slide_path),X_train),
      "grid": uf.get_grid(slide_path,X_train,patches_size,0.6,0.2),
      "targets": y_train,
      "mult": patches_size/224,
      "level": 0,
  }
torch.save(train_output, "{}/{}_train_data.pt".format(output_path,target_gene))
val_output = {
      "slides": uf.make_paths_list("{}renameByUPN/".format(slide_path),X_val),
      "grid": uf.get_grid(slide_path,X_val,patches_size,0.6,0.2),
      "targets": y_val,
      "mult": patches_size/224,
      "level": 0,
  }
torch.save(val_output, "{}/{}_val_data.pt".format(output_path,target_gene))
test_output = {
      "slides": uf.make_paths_list("{}renameByUPN/".format(slide_path),X_test),
      "grid": uf.get_grid(slide_path,X_test,patches_size,0.6,0.2),
      "targets": y_test,
      "mult": patches_size/224,
      "level": 0,
  }
torch.save(test_output, "{}/{}_test_data.pt".format(output_path,target_gene))
# Out:
# slide 22 done, patch_number are 6494.
# slide 25 done, patch_number are 5567.
# slide 29 done, patch_number are 9610.
# slide 102 done, patch_number are 19245.
# slide 104 done, patch_number are 14336.
# slide 106 done, patch_number are 18827.
# slide 109 done, patch_number are 10293.
# slide 124 done, patch_number are 2853.
# slide 129 done, patch_number are 2198.
# slide 130 done, patch_number are 11304.
# slide 133 done, patch_number are 21735.
# slide 134 done, patch_number are 9128.
# slide 135 done, patch_number are 4620.
# slide 137 done, patch_number are 5350.
# slide 145 done, patch_number are 11819.
# slide 150 done, patch_number are 8543.
# slide 151 done, patch_number are 10856.
# slide 154 done, patch_number are 6359.
# slide 158 done, patch_number are 18170.
# slide 159 done, patch_number are 10285.
# slide 160 done, patch_number are 10735.
# slide 161 done, patch_number are 7925.
# slide 162 done, patch_number are 4852.
# slide 165 done, patch_number are 15347.
# slide 166 done, patch_number are 27975.
# slide 167 done, patch_number are 8253.
# slide 171 done, patch_number are 9290.
# slide 172 done, patch_number are 22711.
# slide 174 done, patch_number are 26667.
# slide 177 done, patch_number are 8976.
# slide 178 done, patch_number are 12460.
# slide 197 done, patch_number are 6613.
# slide 203 done, patch_number are 9996.
# slide 206 done, patch_number are 5917.
# slide 208 done, patch_number are 2954.
# slide 209 done, patch_number are 8116.
# slide 212 done, patch_number are 20022.
# slide 219 done, patch_number are 6283.
# slide 220 done, patch_number are 19870.
# slide 224 done, patch_number are 20801.
# slide 231 done, patch_number are 7034.
# slide 234 done, patch_number are 17462.
# slide 235 done, patch_number are 3828.
# slide 241 done, patch_number are 7796.
# slide 242 done, patch_number are 11369.
# slide 244 done, patch_number are 4339.
# slide 257 done, patch_number are 8465.
# slide 265 done, patch_number are 7995.
# slide 273 done, patch_number are 4818.
# slide 274 done, patch_number are 22823.
# slide 292 done, patch_number are 10852.
# slide 308 done, patch_number are 797.
# slide 314 done, patch_number are 13996.
# slide 326 done, patch_number are 12593.
# slide 330 done, patch_number are 2127.
# slide 332 done, patch_number are 14063.
# slide 333 done, patch_number are 7633.
# slide 337 done, patch_number are 13897.
# slide 341 done, patch_number are 808.
# slide 343 done, patch_number are 18115.
# slide 347 done, patch_number are 6709.
# slide 348 done, patch_number are 6684.
# slide 349 done, patch_number are 7976.
# slide 352 done, patch_number are 16721.
# slide 355 done, patch_number are 9350.
# slide 357 done, patch_number are 12463.
# slide 359 done, patch_number are 5030.
# slide 361 done, patch_number are 6733.
# slide 363 done, patch_number are 2854.
# slide 366 done, patch_number are 10063.
# slide 367 done, patch_number are 10434.
# slide 368 done, patch_number are 14953.
# slide 369 done, patch_number are 4400.
# slide 370 done, patch_number are 6508.
# slide 372 done, patch_number are 5045.
# slide 373 done, patch_number are 2549.
# slide 374 done, patch_number are 21319.
# slide 377 done, patch_number are 18219.
# slide 378 done, patch_number are 13842.
# slide 380 done, patch_number are 3882.
# slide 381 done, patch_number are 1232.
# slide 384 done, patch_number are 524.
# slide 385 done, patch_number are 9560.
# slide 386 done, patch_number are 14305.
# slide 387 done, patch_number are 3634.
# slide 390 done, patch_number are 6769.
# slide 392 done, patch_number are 2350.
# slide 393 done, patch_number are 6153.
# slide 397 done, patch_number are 10896.
# slide 401 done, patch_number are 6135.
# slide 402 done, patch_number are 6019.
# slide 404 done, patch_number are 4361.
# slide 405 done, patch_number are 2560.
# slide 408 done, patch_number are 5375.
# slide 409 done, patch_number are 16821.
# slide 410 done, patch_number are 1332.
# slide 415 done, patch_number are 4516.
# slide 423 done, patch_number are 4759.
# slide 425 done, patch_number are 7671.
# slide 426 done, patch_number are 19427.
# slide 429 done, patch_number are 8802.
# slide 431 done, patch_number are 21925.
# slide 438 done, patch_number are 25967.
# slide 443 done, patch_number are 21733.
# slide 445 done, patch_number are 5518.
# slide 448 done, patch_number are 11316.
# slide 449 done, patch_number are 1955.
# slide 453 done, patch_number are 11071.
# slide 454 done, patch_number are 15297.
# slide 455 done, patch_number are 13098.
# slide 459 done, patch_number are 5158.
# slide 461 done, patch_number are 3954.
# slide 462 done, patch_number are 9483.
# slide 463 done, patch_number are 2333.
# slide 465 done, patch_number are 5789.
# slide 471 done, patch_number are 2561.
# slide 472 done, patch_number are 1597.
# slide 476 done, patch_number are 6148.
# slide 477 done, patch_number are 5390.
# slide 478 done, patch_number are 8749.
# slide 482 done, patch_number are 6279.
# slide 485 done, patch_number are 14233.
# slide 487 done, patch_number are 14495.
# slide 488 done, patch_number are 5420.
# slide 490 done, patch_number are 10896.
# slide 491 done, patch_number are 9193.
# slide 492 done, patch_number are 1176.
# slide 494 done, patch_number are 12198.
# slide 512 done, patch_number are 4643.
# slide 514 done, patch_number are 3724.
# slide 519 done, patch_number are 9272.
# slide 522 done, patch_number are 18347.
# slide 527 done, patch_number are 11117.
# slide 531 done, patch_number are 1547.
# slide 534 done, patch_number are 11839.
# slide 538 done, patch_number are 6421.
# slide 539 done, patch_number are 643.
# slide 549 done, patch_number are 2507.
# slide 554 done, patch_number are 17228.
# slide 560 done, patch_number are 18570.
# slide 570 done, patch_number are 7559.
# slide 579 done, patch_number are 12307.
# slide 581 done, patch_number are 11858.
# slide 590 done, patch_number are 12321.
# slide 592 done, patch_number are 5789.
# slide 593 done, patch_number are 26541.
# slide 594 done, patch_number are 9796.
# slide 598 done, patch_number are 9681.
# slide 600 done, patch_number are 20820.
# slide 603 done, patch_number are 11226.
# slide 605 done, patch_number are 14641.
# slide 606 done, patch_number are 5762.
# slide 607 done, patch_number are 17875.
# slide 609 done, patch_number are 14610.
# slide 610 done, patch_number are 10254.
# slide 612 done, patch_number are 14562.
# slide 614 done, patch_number are 15844.
# slide 615 done, patch_number are 16694.
# slide 620 done, patch_number are 8329.
# slide 626 done, patch_number are 15278.
# slide 628 done, patch_number are 9456.
# slide 630 done, patch_number are 3316.
# slide 631 done, patch_number are 4689.
# slide 632 done, patch_number are 5608.
# slide 636 done, patch_number are 13187.
# slide 639 done, patch_number are 8512.
# slide 642 done, patch_number are 5617.
# slide 643 done, patch_number are 4217.
# slide 647 done, patch_number are 5259.
# slide 648 done, patch_number are 6047.
# slide 654 done, patch_number are 17232.
# slide 655 done, patch_number are 9124.
# slide 656 done, patch_number are 7221.
# slide 657 done, patch_number are 12714.
# slide 662 done, patch_number are 5937.
# slide 664 done, patch_number are 26534.
# slide 665 done, patch_number are 19534.
# slide 666 done, patch_number are 10010.
# slide 669 done, patch_number are 9046.
# slide 670 done, patch_number are 28280.
# slide 674 done, patch_number are 9727.
# slide 714 done, patch_number are 7466.
# slide 716 done, patch_number are 27763.
# slide 717 done, patch_number are 8555.
# slide 718 done, patch_number are 13447.
# slide 721 done, patch_number are 11759.
# slide 722 done, patch_number are 10058.
# slide 723 done, patch_number are 10216.
# slide 726 done, patch_number are 18782.
# slide 729 done, patch_number are 13601.
# slide 732 done, patch_number are 18311.
# slide 738 done, patch_number are 10491.
# slide 740 done, patch_number are 12011.
# slide 742 done, patch_number are 6862.
# slide 745 done, patch_number are 4137.
# slide 750 done, patch_number are 15102.
# slide 755 done, patch_number are 14847.
# slide 757 done, patch_number are 8927.
# slide 758 done, patch_number are 4763.
# slide 760 done, patch_number are 2133.
# slide 762 done, patch_number are 16389.
# slide 763 done, patch_number are 14609.
# slide 764 done, patch_number are 23338.
# slide 767 done, patch_number are 10397.
# slide 771 done, patch_number are 8803.
# slide 782 done, patch_number are 5686.
# slide 783 done, patch_number are 6216.
# slide 788 done, patch_number are 2085.
# slide 789 done, patch_number are 8108.
# slide 790 done, patch_number are 3517.
# slide 792 done, patch_number are 8953.
# slide 794 done, patch_number are 8436.
# slide 795 done, patch_number are 1847.
# slide 798 done, patch_number are 9811.
# slide 803 done, patch_number are 5106.
# slide 808 done, patch_number are 6477.
# slide 811 done, patch_number are 14326.
# slide 812 done, patch_number are 23304.
# slide 814 done, patch_number are 15010.
# slide 815 done, patch_number are 8521.
# slide 816 done, patch_number are 3651.
# slide 819 done, patch_number are 18847.
# slide 821 done, patch_number are 8627.
# slide 824 done, patch_number are 12197.
# slide 827 done, patch_number are 6602.
# slide 828 done, patch_number are 4063.
# slide 830 done, patch_number are 8933.
# slide 832 done, patch_number are 5754.
# slide 836 done, patch_number are 12799.
# slide 837 done, patch_number are 9859.
# slide 841 done, patch_number are 16461.
# slide 846 done, patch_number are 13385.
# slide 847 done, patch_number are 4034.
# slide 852 done, patch_number are 7287.
# slide 862 done, patch_number are 2559.
# slide 869 done, patch_number are 15700.
# slide 872 done, patch_number are 3294.
# slide 883 done, patch_number are 21942.
# slide 896 done, patch_number are 3074.
# slide 901 done, patch_number are 1183.
# slide 914 done, patch_number are 2782.
# slide 934 done, patch_number are 18137.
# slide 936 done, patch_number are 10660.
# slide 938 done, patch_number are 11391.
# slide 942 done, patch_number are 9517.
# slide 943 done, patch_number are 1914.
# slide 946 done, patch_number are 8826.
# slide 948 done, patch_number are 7012.
# slide 949 done, patch_number are 20316.
# slide 952 done, patch_number are 10662.
# slide 957 done, patch_number are 8545.
# slide 958 done, patch_number are 13723.
# slide 964 done, patch_number are 5553.
# slide 967 done, patch_number are 11721.
# slide 971 done, patch_number are 4270.
# slide 974 done, patch_number are 11104.
# slide 977 done, patch_number are 10484.
# slide 978 done, patch_number are 9749.
# slide 981 done, patch_number are 2875.
# slide 982 done, patch_number are 5598.
# slide 983 done, patch_number are 9362.
# slide 985 done, patch_number are 4536.
# slide 986 done, patch_number are 3615.
# slide 988 done, patch_number are 6056.
# slide 991 done, patch_number are 23075.
# slide 993 done, patch_number are 14367.
# slide 994 done, patch_number are 15559.
# slide 997 done, patch_number are 3027.
# slide 999 done, patch_number are 21179.
# slide 1002 done, patch_number are 9016.
# slide 1004 done, patch_number are 9613.
# slide 1005 done, patch_number are 5613.
# slide 1007 done, patch_number are 14186.
# slide 1014 done, patch_number are 2521.
# slide 1016 done, patch_number are 3483.
# slide 1017 done, patch_number are 11090.
# slide 1025 done, patch_number are 17878.
# slide 1027 done, patch_number are 1884.
# slide 1028 done, patch_number are 14357.
# slide 1029 done, patch_number are 3813.
# slide 1034 done, patch_number are 4144.
# slide 1036 done, patch_number are 9996.
# slide 1037 done, patch_number are 13448.
# slide 1039 done, patch_number are 6234.
# slide 1043 done, patch_number are 7121.
# slide 1047 done, patch_number are 9904.
# slide 1048 done, patch_number are 5832.
# slide 1049 done, patch_number are 2525.
# slide 1057 done, patch_number are 10318.
# slide 1058 done, patch_number are 21044.
# slide 1059 done, patch_number are 3550.
# slide 1060 done, patch_number are 4403.
# slide 1065 done, patch_number are 8149.
# slide 1066 done, patch_number are 969.
# slide 1069 done, patch_number are 13414.
# slide 1074 done, patch_number are 12930.
# slide 1076 done, patch_number are 10012.
# slide 1080 done, patch_number are 4423.
# slide 1082 done, patch_number are 3113.
# slide 1083 done, patch_number are 10928.
# slide 1086 done, patch_number are 15268.
# slide 1092 done, patch_number are 1457.
# slide 1093 done, patch_number are 8351.
# slide 1095 done, patch_number are 11668.
# slide 1098 done, patch_number are 9768.
# slide 1099 done, patch_number are 12346.
# slide 1100 done, patch_number are 2074.
# slide 1101 done, patch_number are 4410.
# slide 1102 done, patch_number are 5150.
# slide 1110 done, patch_number are 9666.
# slide 1114 done, patch_number are 10799.
# slide 1115 done, patch_number are 10678.
# slide 1119 done, patch_number are 8907.
# slide 1122 done, patch_number are 2632.
# slide 1124 done, patch_number are 15638.
# slide 1132 done, patch_number are 14178.
# slide 1134 done, patch_number are 7993.
# slide 1142 done, patch_number are 13864.
# slide 1144 done, patch_number are 5836.
# slide 1149 done, patch_number are 19028.
# slide 1150 done, patch_number are 6329.
# slide 1151 done, patch_number are 14354.
# slide 1153 done, patch_number are 16972.
# slide 1154 done, patch_number are 3515.
# slide 1155 done, patch_number are 15271.
# slide 1156 done, patch_number are 18972.
# slide 1157 done, patch_number are 13575.
# slide 1159 done, patch_number are 9132.
# slide 1160 done, patch_number are 9464.
# slide 1161 done, patch_number are 2832.
# slide 1165 done, patch_number are 6722.
# slide 1169 done, patch_number are 6968.
# slide 1170 done, patch_number are 14585.
# slide 1172 done, patch_number are 15004.
# slide 1175 done, patch_number are 8485.
# slide 1177 done, patch_number are 9902.
# slide 1197 done, patch_number are 12676.
# slide 1199 done, patch_number are 8892.
# slide 1201 done, patch_number are 7641.
# slide 1236 done, patch_number are 2989.
# slide 1306 done, patch_number are 5318.
# slide 1308 done, patch_number are 6719.
# slide 1315 done, patch_number are 11108.
# slide 1327 done, patch_number are 9033.
